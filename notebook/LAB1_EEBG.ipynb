# %% [markdown]
# #**Lab Assignment 1: Creating organized file structures for your projects**

# %% [markdown]
# ##**Introduction**

# %% [markdown]
# Keeping organized is an important aspect of efficient research. From saving time to preventing confusion with your collaborators, documenting and organizing one's project files is essential for producing transparent and reproducible results.
#
# To this end, README files can be used to help users of your research (including your future self) to navigate through the many files you produce by providing descriptions for all files and folders stored in its directory.
#
# As such, today you will practice using Unix commands to produce an organized file structure to share the results of your research.

# %% [markdown]
# ##**Instructions**

# %% [markdown]
# In a copy of this Colab notebook, use the commands presented in the previous sections to replicate the file structure depicted below. You will be graded based on how similar your file structure is to the one in the diagram.
#
# To start, click the File tab at the top of your screen.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Then, select `Save a copy in Drive` to save a copy of this notebook in your own Google Drive.
#
# Next, replicate the file structure shown here with a `Repository` directory saved inside `/content`.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here, all directories are colored blue, all README files are colored green, and all other files are colored yellow-orange. Additionally, the `summarydata` directory stores tabular data files, the `notebook` directory stores IPython notebook files, the `figure` directory stores your project's figures, and the `multipanel` directory stores combined, multi-panel figures.
#
# It is acceptable for all files to be empty as long as they are named according to the schematic above.

# %% [markdown]
# #**Daniela Cebotari LAB 1, UNIX Commands**#

# %% [markdown]
# ##**Exercising using only `pwd` , `mkdir`, `ls`, `cd` and `touch` commands.**##

# %% [markdown]
# To start off I checked the directory, even if all starts with /content.

# %%
# %%bash
# pwd
# Out:
# /content

# %% [markdown]
# Created the subdirectory /Repository that this lab works around.

# %%
# %%bash
# mkdir Repository
# ls
# Out:
# Repository
# sample_data

# %% [markdown]
# The README file that is in the same location as the subdirectories.

# %%
# %%bash
# cd Repository
# touch README.txt
# ls
# Out:
# README.txt

# %% [markdown]
# Here I created all needed subdirectories at once.

# %%
# %%bash
# cd Repository
# mkdir summarydata
# mkdir notebook
# mkdir figure
# mkdir multipanel
# ls
# Out:
# figure
# multipanel
# notebook
# README.txt
# summarydata

# %% [markdown]
# Then I proceeded to create each README file separately in each subdirectory, not at the same time as the other files in the respective folder, because why not.

# %%
# %%bash
# cd Repository
# cd summarydata
# touch README.txt
# ls
# Out:
# README.txt

# %%
# %%bash
# cd Repository
# cd notebook
# touch README.txt
# ls
# Out:
# README.txt

# %%
# %%bash
# cd Repository
# cd figure
# touch README.txt
# ls
# Out:
# README.txt

# %%
# %%bash
# cd Repository
# cd multipanel
# touch README.txt
# ls
# Out:
# README.txt

# %% [markdown]
# Then, knowing I have all README files, went on to create all needed files for each subdirectory.

# %%
# %%bash
# cd Repository
# cd multipanel
# touch Figure1.ai
# touch Figure2.ai
# ls
# Out:
# Figure1.ai
# Figure2.ai
# README.txt

# %%
# %%bash
# cd Repository
# cd figure
# touch Figure1a.pdf
# touch Figure1b.pdf
# touch Figure2a.pdf
# touch Figure2b.pdf
# touch Figure2c.pdf
# ls
# Out:
# Figure1a.pdf
# Figure1b.pdf
# Figure2a.pdf
# Figure2b.pdf
# Figure2c.pdf
# README.txt

# %%
# %%bash
# cd Repository
# cd notebook
# touch Figure1.ipynb
# touch Figure2.ipnyb
# ls
# Out:
# Figure1.ipynb
# Figure2.ipnyb
# README.txt

# %%
# %%bash
# cd Repository
# cd summarydata
# touch Figure_1adata.csv
# touch Figure_1bdata.csv
# touch Figure_2adata.csv
# touch Figure_2bdata.csv
# touch Figure_2cdata.csv
# ls
# Out:
# Figure_1adata.csv
# Figure_1bdata.csv
# Figure_2adata.csv
# Figure_2bdata.csv
# Figure_2cdata.csv
# README.txt

# %% [markdown]
# Checking all contents of /Repository.

# %%
# %%bash
# ls Repository
# Out:
# figure
# multipanel
# notebook
# README.txt
# summarydata

# %% [markdown]
# Went on to check all contents of each subdirectory individually to be sure.

# %%
# %%bash
# cd Repository
# ls figure
# Out:
# Figure1a.pdf
# Figure1b.pdf
# Figure2a.pdf
# Figure2b.pdf
# Figure2c.pdf
# README.txt

# %%
# %%bash
# cd Repository
# ls multipanel
# Out:
# Figure1.ai
# Figure2.ai
# README.txt

# %%
# %%bash
# cd Repository
# ls notebook
# Out:
# Figure1.ipynb
# Figure2.ipnyb
# README.txt

# %%
# %%bash
# cd Repository
# ls summarydata
# Out:
# Figure_1adata.csv
# Figure_1bdata.csv
# Figure_2adata.csv
# Figure_2bdata.csv
# Figure_2cdata.csv
# README.txt

# %% [markdown]
# I succesfully completed this assignment :p Now on to playing with the other commands.

# %% [markdown]
# ##**Exercising using other commands.**##

# %% [markdown]
# ###**When manipulating files. Using `mv`, `cp`, `rm` commands.**###

# %%
# %%bash
# cd Repository
# mv README.txt READ_ME.txt
# ls
# Out:
# figure
# multipanel
# notebook
# READ_ME.txt
# summarydata

# %%
# %%bash
# cd Repository
# cp READ_ME.txt README.txt
# ls
# Out:
# figure
# multipanel
# notebook
# READ_ME.txt
# README.txt
# summarydata

# %%
# %%bash
# cd Repository
# rm READ_ME.txt
# ls
# Out:
# figure
# multipanel
# notebook
# README.txt
# summarydata

# %% [markdown]
# ###**When manipulating directories. Using `mv`, `cp -r`, `rm -r` commands.**###

# %%
# %%bash
# cd Repository
# mv notebook note_book
# ls
# Out:
# figure
# multipanel
# note_book
# README.txt
# summarydata

# %%
# %%bash
# cd Repository
# cp -r note_book notebook
# ls
# Out:
# figure
# multipanel
# note_book
# notebook
# README.txt
# summarydata

# %%
# %%bash
# cd Repository
# rm -r note_book
# ls
# Out:
# figure
# multipanel
# notebook
# README.txt
# summarydata
